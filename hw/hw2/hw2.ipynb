# %% [markdown]
# # Setup

# %%
from bokeh.io import output_notebook, show
from bokeh.models import CustomJS, ColumnDataSource, Slider, CDSView, IndexFilter
from bokeh.models.widgets import Select
from bokeh.layouts import column
from bokeh.plotting import figure
from bokeh.charts import Line, Scatter
import pandas as pd
import numpy as np

#Set output to notebook
output_notebook()

#Read in correct data and missing data
df = pd.read_csv("data.csv")
df_missing = pd.read_csv("data-missing.csv")

#Focus on rows with missing values and the corresponding correct rows
rows_missing = df_missing[df_missing.isnull().any(axis=1)]
rows_correct = df[df_missing.isnull().any(axis=1)]

print(rows_missing)
print(rows_correct)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3b8d0d5e-dbbc-46f8-9a2e-7003d36b29db">Loading BokehJS ...</span>
#     </div>
#      Channel  Region  Fresh    Milk  Grocery  Frozen  Detergents_Paper  \
# 75         1       3  20398  1137.0      NaN    4407               3.0
# 172        1       3    955  5479.0      NaN     333            2840.0
# 180        1       3  12356     NaN   8887.0     402            1382.0
# 225        1       1  12680  3243.0   4157.0     660               NaN
# 274        1       3    894  1703.0   1841.0     744             759.0
# 370        2       3  39679  3944.0   4955.0    1364               NaN
#
#      Delicassen
# 75        975.0
# 172       707.0
# 180      2794.0
# 225       786.0
# 274         NaN
# 370      2235.0
#      Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  \
# 75         1       3  20398  1137        3    4407                 3
# 172        1       3    955  5479     6536     333              2840
# 180        1       3  12356  6036     8887     402              1382
# 225        1       1  12680  3243     4157     660               761
# 274        1       3    894  1703     1841     744               759
# 370        2       3  39679  3944     4955    1364               523
#
#      Delicassen
# 75          975
# 172         707
# 180        2794
# 225         786
# 274        1153
# 370        2235
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-fe3da61c180b> in <module>()
#      23
#      24 s1 = figure(width=250, plot_height=250, title=None)
# ---> 25 s1.Line(
#      26         rows_missing.loc[:,'Fresh':'Delicassen'],
#      27         title="Missing",
#
# AttributeError: 'Figure' object has no attribute 'Line'

# %% [markdown]
# # Display missing and correct data

# %%
line1 = Line(
        rows_missing.loc[:,'Fresh':'Delicassen'], 
        title="Missing", 
        legend="top_right", 
        ylabel='Value'
    )
line2 = Line(
        rows_correct.loc[:,'Fresh':'Delicassen'], 
        title="Correct", 
        legend="top_right", 
        ylabel='Value',
        x_range=line1.x_range, 
        y_range=line1.y_range
    )


show(row(line1, line2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bbf87391-8b6f-4b5c-9a43-c48808c760ba"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("bbf87391-8b6f-4b5c-9a43-c48808c760ba");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bbf87391-8b6f-4b5c-9a43-c48808c760ba");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bbf87391-8b6f-4b5c-9a43-c48808c760ba' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"daceac9a-8f3f-4813-8d04-dd5d369cc879":{"roots":{"references":[{"attributes":{},"id":"b2ca708b-66df-4d80-8104-6b2af0062806","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"Frozen"},{"series":"Frozen"},{"series":"Frozen"},{"series":"Frozen"},{"series":"Frozen"},{"series":"Frozen"}],"series":["Frozen","Frozen","Frozen","Frozen","Frozen","Frozen"],"x_values":[75,172,180,225,274,370],"y_values":{"__ndarray__":"AAAAAAA3sUAAAAAAANB0QAAAAAAAIHlAAAAAAACghEAAAAAAAECHQAAAAAAAUJVA","dtype":"float64","shape":[6]}}},"id":"285c4e5b-35ee-48ef-a05f-c7dc0d49e796","type":"ColumnDataSource"},{"attributes":{"plot":{"id":
type":"LinearAxis"}],"css_classes":null,"left":[{"id":"f6066277-21f9-404f-b615-f9dc1c1ff726","type":"LinearAxis"}],"renderers":[{"id":"41c65712-689a-4bb3-b6f4-ae528a457b9f","type":"BoxAnnotation"},{"id":"05ea35ed-43bc-496f-9731-d2d6fbd00624","type":"GlyphRenderer"},{"id":"9940f74f-cad8-407b-9307-a3e2dc79b7b4","type":"GlyphRenderer"},{"id":"843e2001-2fa3-4253-899d-484254e512f0","type":"GlyphRenderer"},{"id":"b4a231c4-7cf3-42a0-b823-8b3efb6124db","type":"GlyphRenderer"},{"id":"18de6b8c-7a41-4387-8626-0173a975b669","type":"GlyphRenderer"},{"id":"a2068672-6bc7-4f79-b785-a39d1b752cd0","type":"GlyphRenderer"},{"id":"84e3b7d2-8bb2-4487-8442-4ac9d78c0bc2","type":"Legend"},{"id":"aaf53c6a-9c43-4d50-b1c1-28ff4e991d7a","type":"LinearAxis"},{"id":"f6066277-21f9-404f-b615-f9dc1c1ff726","type":"LinearAxis"},{"id":"2854442e-6c7c-49ee-8 ...

# %% [markdown]
# # Impute using attribute mean

# %%
rows_missing = rows_missing.fillna(df_missing.mean().astype(int))
line1 = Line(
        rows_missing.loc[:,'Fresh':'Delicassen'], 
        title="Missing", 
        legend="top_right", 
        ylabel='Value'
    )
line2 = Line(
        rows_correct.loc[:,'Fresh':'Delicassen'], 
        title="Correct", 
        legend="top_right", 
        ylabel='Value',
        x_range=line1.x_range, 
        y_range=line1.y_range
    )


show(row(line1, line2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2af411d6-4c9c-440a-8d65-a878f7c85336"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("2af411d6-4c9c-440a-8d65-a878f7c85336");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2af411d6-4c9c-440a-8d65-a878f7c85336");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2af411d6-4c9c-440a-8d65-a878f7c85336' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b20534c5-9266-480b-95d3-92dec680ffea":{"roots":{"references":[{"attributes":{},"id":"f6e5efe9-655b-4dcd-88b5-08aac2632835","type":"SaveTool"},{"attributes":{"line_color":{"value":"#00ad9c"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"c92c18b7-599e-4f34-bd87-2413a7874fb1","type":"Line"},{"attributes":{"overlay":{"id":"6f2e3d03-5f67-4366-a66b-af29ec3d3fc5","type":"BoxAnnotation"}},"id":"b72c081c-eff1-4926-9382-650a11e55152","type":"BoxZoomTool"},{"attributes":{"line_color":{"value":"#00ad9c"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"f69b255d-0350-4dae-ade3-08448992602e","type":"Line"},{"attributes":{},"id":"4029b031-9a9e-4860-a3c9-773070849e14","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"Detergents_Paper"},{"series":"Detergents_Paper"},{"series":"Detergents_Paper"},{"series":"Detergents_Paper"},{"series":"Detergents_Paper"},{"series":"Detergents_Paper"}],"series":["Detergents_Paper","Detergents_Paper","Detergents_Paper","Detergents_Paper","Detergents_Paper","Detergents_Paper"],"x_values":[75,172,180,225,274,370],"y_values":{"__ndarray__":"AAAAAAAACEAAAAAAADCmQAAAAAAAmJVAAAAAAACWpkAAAAAAALiHQAAAAAAAlqZA","dtype":"float64","shape":[6]}}},"id":"0d81f387-2e1c-48b2-b013-512ba3f7709e","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"5769fb88-a8ce-4b2e-898c-6b24db01f407","subtype":"Chart","type":"Plot"},"ticker":{"id":"0b83d424-f1ec-46e2-bbf6-5d4c056b1646","type":"BasicTicker"}},"id":"e9966d9a-5b01-4d24-a56d-102888d8b4a1","type":"Grid"},{"attributes":{"line_color":{"value":"#5ab738"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"e625c727-5443-4a96-a831-026757ad510b","type":"Line"},{"attributes":{},"id":"ef17ede8-bd12-4165-a406-c70ea2102454","type":"WheelZoomTool"},{"attributes":{"label":{"value":"Delicassen"},"renderers":[{"id":"145a35d6-90ff-4785-b8fa-db77d7fe0c7b","type":"GlyphRenderer"}]},"id":"2e369fda-d380-4ba4-9241-7b7d02ae33c4","type":"LegendItem"},{"attributes":{"label":{"value":"Detergents_Paper"},"renderers":[{"id":"6d3c742e-757c-41ce-91aa-20b73ae4931e","type":"GlyphRenderer"}]},"id":"294bdf74-e19f-4a44-8480-3b9bc7494527","type":"LegendItem"},{"attributes":{},"id":"84bd8b17-a754-42c5-b090-5ffd39193be1","type":"BasicTicker"},{"attributes":{},"id":"9d83df2d-3ab9-42fc-aa88-3cca83cf1898","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"Fresh"},{"series":"Fresh"},{"series":"Fresh"},{"series":"Fresh"},{"series":"Fresh"},{"series":"Fresh"}],"series":["Fresh","Fresh","Fresh","Fresh","Fresh","Fresh"],"x_values":[75,172,180,225,274,370],"y_values":{"__ndarray__":"AAAAAIDr00AAAAAAANiNQAAAAAAAIshAAAAAAADEyEAAAAAAAPCLQAAAAADgX+NA","dtype":"float64","shape":[6]}}},"id":"8a37220c-99da-482b-ac00-341421c54a92","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#df5320"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"ec9390c4-1246-4be4-8e7d-ec2aad9f540e","type":"Line"},{"attributes":{"axis_label":"Value","formatter":{"id":"9d83df2d-3ab9-42fc-aa88-3cca83cf1898","type":"BasicTickFormatter"},"plot":{"id":"491c0fce-c754-425a-87cf-03c5605262c4","subtype":"Chart","type":"Plot"},"ticker":{"id":"0e818af2-1d51-482a-acd0-f70ce3ff64f9","type":"BasicTicker"}},"id":"20fce8a7-5220-4680-a678-8d4b347a4a37","type":"LinearAxis"},{"attributes":{"source":null},"id":"228eea97-5921-4414-b76e-862de3a62d17","type":"CDSView"},{"attributes":{"data_source":{"id":"ff98f039-fb8a-4d92-8813-510a34da8396","type":"ColumnDataSource"},"glyph":{"id":"db532821-2afb-45e6-bc63-73feac11964a","type":"Line"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"67034504-d09d-4681-889d-a63d8f95965d","type":"CDSView"}},"id":"2245a76a-3a73-444b-863e-ae71bb8045be","type":"GlyphRenderer"},{"attributes":{"label":{"value":"Detergen ...

# %% [markdown]
# # Impute using attribute median

# %%
rows_missing = rows_missing.fillna(df_missing.median().astype(int))
line1 = Line(
        rows_missing.loc[:,'Fresh':'Delicassen'], 
        title="Missing", 
        legend="top_right", 
        ylabel='Value'
    )
line2 = Line(
        rows_correct.loc[:,'Fresh':'Delicassen'], 
        title="Correct", 
        legend="top_right", 
        ylabel='Value',
        x_range=line1.x_range, 
        y_range=line1.y_range
    )


show(row(line1, line2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="18645405-e725-477b-8305-043a23f4db50"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById
2fd33245e","type":"BasicTickFormatter"},{"attributes":{},"id":"347b8cad-e3e8-4313-9886-dd4b8665b20b","type":"WheelZoomTool"},{"attributes":{"axis_label":"index","formatter":{"id":"bea7efec-f0d4-4d8c-b8fe-ffb2fd33245e","type":"BasicTickFormatter"},"plot":{"id":"f0918e83-ba9a-48f4-937b-9bedc827af2c","subtype":"Chart","type":"Plot"},"ticker":{"id":"290b9f16-7dde-4c44-aae4-ee0b982502ce","type":"BasicTicker"}},"id":"51ef6282-85c4-48db-a216-de3809122aae","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"Milk"},{"series":"Milk"},{"series":"Milk"},{"series":"Milk"},{"series":"Milk"},{"series":"Milk"}],"series":["Milk","Milk","Milk","Milk","Milk","Milk"],"x_values":[75,172,180,225,274,370],"y_values":[1137,5479,6036,3243,1703,3944]}},"id":"0762a683-0538-4576-b63a-765831f7e381","type":"ColumnDataSource"},{"attributes":{"label":{"value":"Grocery"},"renderers":[{"id":"ee1a114a-4041-4582-ac87-65f3740d7b0e","type":"GlyphRenderer"}]},"id":"95e80f9b-08e7-4e4a-b397-e49c6547afd5","type":"LegendItem"},{"attributes":{},"id":"b7d51d51-b37f-49a7-b142-a43816341409","type":"BasicTickFormatter"},{"attributes":{"labe ...

# %% [markdown]
# # Impute using pandas interpolation

# %%
rows_missing = df_missing[df_missing.isnull().any(axis=1)]
df_interpolated = df_missing.interpolate()
rows_interpolated = df_interpolated.loc[rows_missing.index]

line1 = Line(
        rows_interpolated.loc[:,'Fresh':'Delicassen'], 
        title="Missing", 
        legend="top_right", 
        ylabel='Value'
    )
line2 = Line(
        rows_correct.loc[:,'Fresh':'Delicassen'], 
        title="Correct", 
        legend="top_right", 
        ylabel='Value',
        x_range=line1.x_range, 
        y_range=line1.y_range
    )


show(row(line1, line2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="80a7fb46-f2de-417c-bc9a-553e13b2a0ec"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("80a7fb46-f2de-417c-bc9a-553e13b2a0ec");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("80a7fb46-f2de-417c-bc9a-553e13b2a0ec");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '80a7fb46-f2de-417c-bc9a-553e13b2a0ec' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b8772819-e9d5-4fa1-ae73-0bedfec089a5":{"roots":{"references":[{"attributes":{"line_color":{"value":"#00ad9c"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"deb9f869-1590-449c-9b4e-2eb030b819c1","type":"Line"},{"attributes":{"line_color":{"value":"#df5320"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"d8a78576-f243-4900-a5b7-b97de782cf3c","type":"Line"},{"attributes":{"line_color":{"value":"#f22c40"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"2d3f4827-91dc-4418-9045-eb0547c2e6e8","type":"Line"},{"attributes":{"plot":null,"text":"Correct"},"id":"c3890ebc-fbe4-4c82-afdb-4ae33cabe9da","type":"Title"},{"attributes":{},"id":"2be6f1d2-8299-4103-abc5-75de6ed4ce77","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"Detergents_Paper"},{"series":"Detergents_Paper"},{"series":"Detergents_Paper"},{"series":"Detergents_Paper"},{"series":"Detergents_Paper"},{"series":"Detergents_Paper"}],"series":["Detergents_Paper","Detergents_Paper","Detergents_Paper","Detergents_Paper","Detergents_Paper","Detergents_Paper"],"x_values":[75,172,180,225,274,370],"y_values":{"__ndarray__":"AAAAAAAACEAAAAAAADCmQAAAAAAAmJVAAAAAAACclEAAAAAAALiHQAAAAAAAqHdA","dtype":"float64","shape":[6]}}},"id":"65b55147-0e3a-4750-8885-3e9cae554612","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"83f70538-86a3-41f7-8a36-59c9044c72a3","type":"ColumnDataSource"},"glyph":{"id":"06099e2c-8b26-4f0d-947f-9d9be44ec2df","type":"Line"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"d45563e0-1bc1-4982-a0e9-6f9cef47337e","type":"CDSView"}},"id":"b5071559-97cb-494b-85dd-882411071626","type":"GlyphRenderer"},{"attributes":{"label":{"value":"Frozen"},"renderers":[{"id":"c933a13f-f27a-42f1-9ef9-ceb3fc3b6141","type":"GlyphRenderer"}]},"id":"7c43345a-4f37-4a5c-bb47-58cf3fcb08a5","type":"LegendItem"},{"attributes":{},"id":"524cc43e-4775-41e1-b43b-066bb1927bd4","type":"LinearScale"},{"attributes":{"below":[{"id":"f7a7affe-3ffe-412a-98b9-c6fdc74b4872","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"f157f70f-b96e-4300-9368-75dbf9744ee3","type":"LinearAxis"}],"renderers":[{"id":"f549fea5-64aa-47e8-b775-b5f2957f5030","type":"BoxAnnotation"},{"id":"81e33e2a-beae-4185-bef5-e0c3a4f4acda","type":"GlyphRenderer"},{"id":"5788762a-d63c-4960-904e-d7ce7cf95d96","type":"GlyphRenderer"},{"id":"2c33528c-b2b1-44be-84b8-43d0d6caaa00","type":"GlyphRenderer"},{"id":"be708da6-233d-433d-80ec-ff7a2f82d604","type":"GlyphRenderer"},{"id":"c8ff87e7-9eb3-4765-bf29-868919b93887","type":"GlyphRenderer"},{"id":"b72a12ab-530f-426a-a9a4-c5702e1e43f1","type":"GlyphRenderer"},{"id":"7ae56707-a65f-4299-bc08-2dbcfbb1a043","type":"Legend"},{"id":"f7a7affe-3ffe-412a-98b9-c6fdc74b4872","type":"LinearAxis"},{"id":"f157f70f-b96e-4300-9368-75dbf9744ee3","type":"LinearAxis"},{"id":"b8528643-85ff-42ea-ba7c-bdefd1b9ccbc","type":"Grid"},{"id":"c08039d9-20ea-46f4-979c-a50a106ed4ff","type":"Grid"}],"title":{"id":"d5bc702f-5c9c-4072-afed-947978bc7c3a","type":"Title"},"toolbar":{"id":"9822cfc5-049d-4960-8589-2d0453c54348","type":"Toolbar"},"x_range":{"id":"f2827d8f-06eb-4663-a9af-91307bffa522","type":"Range1d"},"x_scale":{"id":"672ca344-cae8-40b8-b85c-75b5741a2581","type":"LinearScale"},"y_range":{"id":"34fed13c-543a-4f6c-b0cd-3c26089abc9d","type":"Range1d"},"y_scale":{"id":"011f723b-1c11-4751-9c73-e5e22004e350","type":"LinearScale"}},"id":"86322889-4107-45f2-9572-3cbc793b907f","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"Detergents_Paper"},{"series":"Detergents_Paper"},{"series":"Detergents_Paper"},{"series":"Detergents_Paper"},{"series":"Detergents_Paper"},{"series":"Detergents_Paper"}],"series":["Detergents_Paper","Detergents_Paper","Detergents_Paper","Detergents_Paper","Detergents_Paper","Detergents_Paper"],"x_v ...
