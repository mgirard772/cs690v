# %% [markdown]
# # Setup

# %%
from bokeh.io import output_notebook, show
from bokeh.models import CustomJS, ColumnDataSource, Slider, CDSView, IndexFilter
from bokeh.models.widgets import Select
from bokeh.layouts import column, row
from bokeh.plotting import figure
from bokeh.charts import Line, Scatter
import pandas as pd
import numpy as np

#Set output to notebook
output_notebook()

#Read in correct data and missing data
df = pd.read_csv("data.csv")
df_missing = pd.read_csv("data-missing.csv")

#Focus on rows with missing values and the corresponding correct rows
rows_missing = df_missing[df_missing.isnull().any(axis=1)]
rows_correct = df[df_missing.isnull().any(axis=1)]

print(rows_missing)
print(rows_correct)
# Out:
# /Users/mm80739/anaconda/lib/python2.7/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# The bokeh.charts API has moved to a separate 'bkcharts' package.
#
# This compatibility shim will remain until Bokeh 1.0 is released.
# After that, if you want to use this API you will have to install
# the bkcharts package explicitly.
#
#   warn(message)
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3a9402af-2ac5-4a86-bdf1-c59bb3199f36">Loading BokehJS ...</span>
#     </div>
#      Channel  Region  Fresh    Milk  Grocery  Frozen  Detergents_Paper  \
# 75         1       3  20398  1137.0      NaN    4407               3.0
# 172        1       3    955  5479.0      NaN     333            2840.0
# 180        1       3  12356     NaN   8887.0     402            1382.0
# 225        1       1  12680  3243.0   4157.0     660               NaN
# 274        1       3    894  1703.0   1841.0     744             759.0
# 370        2       3  39679  3944.0   4955.0    1364               NaN
#
#      Delicassen
# 75        975.0
# 172       707.0
# 180      2794.0
# 225       786.0
# 274         NaN
# 370      2235.0
#      Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  \
# 75         1       3  20398  1137        3    4407                 3
# 172        1       3    955  5479     6536     333              2840
# 180        1       3  12356  6036     8887     402              1382
# 225        1       1  12680  3243     4157     660               761
# 274        1       3    894  1703     1841     744               759
# 370        2       3  39679  3944     4955    1364               523
#
#      Delicassen
# 75          975
# 172         707
# 180        2794
# 225         786
# 274        1153
# 370        2235

# %% [markdown]
# # Display missing and correct data

# %%
line1 = Line(
        rows_missing.loc[:,'Fresh':'Delicassen'], 
        title="Missing", 
        legend="top_right", 
        ylabel='Value'
    )
line2 = Line(
        rows_correct.loc[:,'Fresh':'Delicassen'], 
        title="Correct", 
        legend="top_right", 
        ylabel='Value',
    )


show(row(line1, line2))
# Out:
# No handlers could be found for logger "/Users/mm80739/anaconda/lib/python2.7/site-packages/bokeh/core/validation/check.pyc"
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f5ec11c4-92ea-449c-a302-5db288ccc722"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("f5ec11c4-92ea-449c-a302-5db288ccc722");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f5ec11c4-92ea-449c-a302-5db288ccc722");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f5ec11c4-92ea-449c-a302-5db288ccc722' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7048c0c1-c6cf-4716-b416-d673421f37f2":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"634d1907-32c0-4e9b-952a-8222a8e167ed","subtype":"Chart","type":"Plot"},"ticker":{"id":"a71ecdac-882c-467f-a987-cb5339e29caf","type":"BasicTicker"}},"id":"ce296a12-f305-48da-a57a-f3b921beaa5a","type":"Grid"},{"attributes":{"label":{"value":"Fresh"},"renderers":[{"id":"3008872f-7adf-4f79-b5f3-2d1d343a301f","type":"GlyphRenderer"}]},"id":"966c569d-cf1e-437e-a447-defcd76d8b57","type":"LegendItem"},{"attributes":{},"id":"160a069c-e743-488e-849e-3a980e556f4f","type":"PanTool"},{"attributes":{"label":{"value":"Milk"},"renderers":[{"id":"b90ce5b1-be44-440b-8950-0c659e4ae68c","type":"GlyphRenderer"}]},"id":"5d5afc25-e43c-4582-9127-aac85b9f2943","type":"LegendItem"},{"attributes":{"label":{"value":"Delicassen"},"renderers":[{"id":"c01d5452-79a8-48ea-8949-b471c4e52c9f","type":"GlyphRenderer"}]},"id":"66d13fa2-c51b-488b-9f0a-edcdb9319073","type":"LegendItem"},{"attributes":{"label":{"value":"Fresh"},"renderers":[{"id":"4fee8ce4-11c6-40dc-b1a6-640205b1d116","type":"GlyphRenderer"}]},"id":"4d627907-70eb-425a-8083-fac986850e3a","type":"LegendItem"},{"attributes":{},"id":"3e36ae5d-3079-4b52-b81f-eff2a2818f69","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"37ae6f05-b3c6-4e23-9281-f5f29dfc4902","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"5617122a-f466-425d-ae3e-0d9fd9b8afb8","type":"BoxAnnotation"}},"id":"1be22024-bc14-418f-916d-43f71b2b2bb3","type":"BoxZoomTool"},{"attributes":{"label":{"value":"Delicassen"},"renderers":[{"id":"bcc0930a-0607-461a-beab-3c8b509d8115","type":"GlyphRenderer"}]},"id":"b3981254-3897-4bdc-bf97-821b2e625863","type":"LegendItem"},{"attributes":{"source":null},"id":"36bfca9c-88a2-4583-95ee-40ab963f7845","type":"CDSView"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"Frozen"},{"series":"Frozen"},{"series":"Frozen"},{"series":"Frozen"},{"series":"Frozen"},{"series":"Frozen"}],"series":["Frozen","Frozen","Frozen","Frozen","Frozen","Frozen"],"x_values":[75,172,180,225,274,370],"y_values":[4407,333,402,660,744,1364]}},"id":"1d00da92-855d-48db-a13f-a9751dc1dc0c","type":"ColumnDataSource"},{"attributes":{},"id":"17cb7d00-57b0-4ff9-a20c-6049f859fc51","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5617122a-f466-425d-ae3e-0d9fd9b8afb8","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"56b47eea-fe9e-48e2-b629-283d017789dc","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"ff68d44d-0a60-49bb-acb9-20c31410d8e7","type":"LinearAxis"}],"renderers":[{"id":"37ae6f05-b3c6-4e23-9281-f5f29dfc4902","type":"BoxAnnotation"},{"id":"4fee8ce4-11c6-40dc-b1a6-640205b1d116","type":"GlyphRenderer"},{"id":"b90ce5b1-be44-440b-8950-0c659e4ae68c","type":"GlyphRenderer"},{"id":"5335783c-2f98-4783-b20f-28fc462d70d2","type":"GlyphRenderer"},{"id":"1bd880e4-8469-4791-8928-bd948fc26d61","type":"GlyphRenderer"},{"id":"5fe1eba5-9d1c-43d0-9f1c-4a7233d43146","type":"GlyphRenderer"},{"id":"bcc0930a-0607-461a-beab-3c8b509d8115","type":"GlyphRenderer"},{"id":"f83ae4cd-137d-4a54-8335-b2f0800901d5","type":"Legend"},{"id":"56b47eea-fe9e-48e2-b629-283d017789dc","type":"LinearAxis"},{"id":"ff68d44d-0a60-49bb-acb9-20c31410d8e7","type":"LinearAxis"},{"id":"145350f1-fdd0-4c32-8a95-0ec996bebdf4","type":"Grid"},{"id":"ce296a12-f305-48da-a57a-f3b921beaa5a","type":"Grid"}],"title": ...

# %% [markdown]
# # Impute using attribute mean

# %%
rows_missing = df_missing[df_missing.isnull().any(axis=1)]
rows_missing = rows_missing.fillna(df_missing.mean().astype(int))
line1 = Line(
        rows_missing.loc[:,'Fresh':'Delicassen'], 
        title="Missing", 
        legend="top_right", 
        ylabel='Value'
    )
line2 = Line(
        rows_correct.loc[:,'Fresh':'Delicassen'], 
        title="Correct", 
        legend="top_right", 
        ylabel='Value'
    )


show(row(line1, line2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="
type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"Milk"},{"series":"Milk"},{"series":"Milk"},{"series":"Milk"},{"series":"Milk"},{"series":"Milk"}],"series":["Milk","Milk","Milk","Milk","Milk","Milk"],"x_values":[75,172,180,225,274,370],"y_values":{"__ndarray__":"AAAAAADEkUAAAAAAAGe1QAAAAAAAo7ZAAAAAAABWqUAAAAAAAJyaQAAAAAAA0K5A","dtype":"float64","shape":[6]}}},"id":"12b33df5-37d9-4ef1-9a9b-402620e186ec","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"110924ca-f650-442f-9443-2584862c0cd6","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"ba7e98ed-575a-43c3-af22-edb6fa1ac9db","type":"LinearAxis"}],"renderers":[{"id":"30c16c41-6663-44c1-a151-ac0e824ddc06","type":"BoxAnnotation"},{"id":"9b134c62-93c0-4a16-a17c-08abf59c9635","type":"GlyphRenderer"},{"id":"ec7f49c6-f700-4f5e-b0e9-621f35c87bc0","type":"GlyphRenderer"},{"id":"f49d4a79-0010-47ea-8df2-87dcf20b11dd","type":"GlyphRenderer"},{"id":"c9ac7e47-56fa-4d06-ade5-b7b7f94bfbd7","type":"GlyphRenderer"},{"id":"0e21eb8a-c6b7-4dea-a6d6-b21ffd913ba9","type":"GlyphRenderer"},{"id":"a05f8579-ffef-4cb1-9bef-e7a96a3b89ae","type":"GlyphRenderer"},{"id":"11683a69-d072-4081-b6ac-e2e81aa26e77","type":"Legend"},{"id":"110924ca-f650-442f-9443-2584862c0cd6","type":"LinearAxis"},{"id":"ba7e98ed-575a-43c3-af22-edb6fa1ac9db","type":"LinearAxis"},{"id":"bf3da113-79bc-4db4-9950-0a2ff0c0995b","type":"Grid"},{"id":"09d3efb2-7fde-442c-ac1b-553fd1da93e1","type":"Grid"}],"t ...

# %% [markdown]
# # Impute using attribute median

# %%
rows_missing = df_missing[df_missing.isnull().any(axis=1)]
rows_missing = rows_missing.fillna(df_missing.median().astype(int))
line1 = Line(
        rows_missing.loc[:,'Fresh':'Delicassen'], 
        title="Missing", 
        legend="top_right", 
        ylabel='Value'
    )
line2 = Line(
        rows_correct.loc[:,'Fresh':'Delicassen'], 
        title="Correct", 
        legend="top_right", 
        ylabel='Value'
    )


show(row(line1, line2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c0497646-1966-4f6e-8543-7eb5225a0d6a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("c0497646-1966-4f6e-8543-7eb5225a0d6a");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c0497646-1966-4f6e-8543-7eb5225a0d6a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c0497646-1966-4f6e-8543-7eb5225a0d6a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"33afd9af-2137-48bd-ac01-ab1d7802f80b":{"roots":{"references":[{"attributes":{"children":[{"id":"4d5bedb6-a035-417c-b69b-280f25e3a38b","subtype":"Chart","type":"Plot"},{"id":"8786df0e-f559-46e6-b1da-02e4175ac0ce","subtype":"Chart","type":"Plot"}]},"id":"a6b4adb8-1280-443f-8e74-f0f95c6c9bc3","type":"Row"},{"attributes":{"label":{"value":"Delicassen"},"renderers":[{"id":"b2dc750a-8b69-46e4-a8bb-c016ebaee994","type":"GlyphRenderer"}]},"id":"2bd0ae7f-5785-4528-9763-524aee103683","type":"LegendItem"},{"attributes":{},"id":"fefb369b-80ef-461b-b841-892134e762b1","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#5ab738"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"fe21c1d4-7423-4d57-b501-acde8132a6e1","type":"Line"},{"attributes":{"data_source":{"id":"7a9cea1e-45e5-4d89-aa3d-013c68d23c08","type":"ColumnDataSource"},"glyph":{"id":"9074951d-7cae-42af-a9b5-3cc35cfffd8b","type":"Line"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"e7922089-bdcd-43ca-9602-67a2ee119b3f","type":"CDSView"}},"id":"187abc30-9936-42ca-9e79-e4c53147e9fe","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"Frozen"},{"series":"Frozen"},{"series":"Frozen"},{"series":"Frozen"},{"series":"Frozen"},{"series":"Frozen"}],"series":["Frozen","Frozen","Frozen","Frozen","Frozen","Frozen"],"x_values":[75,172,180,225,274,370],"y_values":[4407,333,402,660,744,1364]}},"id":"352b5ad9-269a-4d92-8f9d-f5107c0181a8","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"Fresh"},{"series":"Fresh"},{"series":"Fresh"},{"series":"Fresh"},{"series":"Fresh"},{"series":"Fresh"}],"series":["Fresh","Fresh","Fresh","Fresh","Fresh","Fresh"],"x_values":[75,172,180,225,274,370],"y_values":[20398,955,12356,12680,894,39679]}},"id":"7f5970fc-fe90-40d9-a3c3-be9d6de02d88","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#5ab738"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"3cc0b72c-ffc8-4b6a-8810-96659508eb00","type":"Line"},{"attributes":{"label":{"value":"Grocery"},"renderers":[{"id":"187abc30-9936-42ca-9e79-e4c53147e9fe","type":"GlyphRenderer"}]},"id":"89e8e67a-4779-4798-8a90-56e5e40c5aef","type":"LegendItem"},{"attributes":{"label":{"value":"Frozen"},"renderers":[{"id":"d514543e-3014-4428-b0fb-52bc2bef2d66","type":"GlyphRenderer"}]},"id":"0d0e28a8-f6a3-42b1-97a4-63b5e0b36410","type":"LegendItem"},{"attributes":{"data_source":{"id":"879fbea8-34e9-4a11-bcc5-042c27890cf7","type":"ColumnDataSource"},"glyph":{"id":"fe21c1d4-7423-4d57-b501-acde8132a6e1","type":"Line"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"132f5117-b7c4-40fb-9d22-150ae9115ad1","type":"CDSView"}},"id":"80d5b021-8840-4478-9cdb-04f7f64ad270","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"49a20d9c-a316-4eb1-9ccb-e02121966171","type":"ColumnDataSource"},"glyph":{"id":"3cc0b72c-ffc8-4b6a-8810-96659508eb00","type":"Line"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"8d576af8-63a4-4af2-b847-6c5573c47ed1","type":"CDSView"}},"id":"62a2b09a-6c1c-4b91-9569-89a2f3ae31f6","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#f22c40"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"75b9eac6-cd6d-4d45-bc54-2df204bf4e6e","type":"Line"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"Delicassen"},{"series":"Delicassen"},{"series":"Delicassen"},{"series":"Delicassen"},{"series":"Delicassen"},{"series":"Delicassen"}],"series":["Delicassen","Delicassen","Delicassen","Delicassen","Delicassen","Delicassen"],"x_values":[75,172,180,225,274,370],"y_values":[975,707,2794,786,1153,2235]}},"id":"3176b9a7-2960-4e87-a2fc-b1f217e1d22e","type":"ColumnDataSource"},{"attributes":{},"id":"da8f0996-6659-421e-be5e-a55efd7e0185","type":"PanTool"},{"attributes": ...

# %% [markdown]
# # Impute using pandas interpolation, by row

# %%
rows_missing = df_missing[df_missing.isnull().any(axis=1)]
df_interpolated = df_missing.interpolate(axis = 1)
rows_interpolated = df_interpolated.loc[rows_missing.index]

line1 = Line(
        rows_interpolated.loc[:,'Fresh':'Delicassen'], 
        title="Missing", 
        legend="top_right", 
        ylabel='Value'
    )
line2 = Line(
        rows_correct.loc[:,'Fresh':'Delicassen'], 
        title="Correct", 
        legend="top_right", 
        ylabel='Value'
    )


show(row(line1, line2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="
","type":"Line"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"39743f41-2d74-49a5-a5f9-c0986ffba816","type":"CDSView"}},"id":"680129fa-f84a-4e9c-bd32-c0117768d6b3","type":"GlyphRenderer"},{"attributes":{},"id":"29cc7508-9905-467b-a165-d613cc54e42a","type":"WheelZoomTool"},{"attributes":{"label":{"value":"Grocery"},"renderers":[{"id":"5bc6f8bd-4e0f-4d3f-93bf-73dee885622b","type":"GlyphRenderer"}]},"id":"9bab249b-77ff-4153-be5a-3e8b387539f0","type":"LegendItem"},{"attributes":{"source":null},"id":"280ecec9-7ac6-4b2f-b639-1906e074d6dd","type":"CDSView"},{"attributes":{},"id":"ee85c809-61fa-475d-9452-cafb5e3d2dc1","type":"BasicTickFormatter"},{"attributes":{"source":null},"id":"a75543a4-0479-4376-b5b1-8e68d5ab9960","type":"CDSView"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"Frozen"},{"series":"Frozen"},{"series":"Frozen"},{"series":"Frozen"},{"series":"Frozen"},{"series":"Frozen"}],"series":["Frozen","Frozen","Frozen","Frozen","Frozen","Frozen"],"x_values":[75,172,180,225,274,370],"y_values":{"__ndarray__":"AAAAAAA3sUAAAAAAANB0QAAAAAAAIHlAAAAAAACghEAAAAAAAECHQAAAAAAAUJVA","dtype":"float64","shape":[6]}}},"id":"25df7036-948b-41b8-a90b-973b3dae9d18","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"f679ebe5-e3e4-4197-8fb1-7799aab774e5","type":"BoxAnnotation"}},"id":"af9b366b-34f1-4702-b3dc-89c5560e40cc","type":"BoxZoomTool"},{"att ...

# %% [markdown]
# # Impute using pandas interpolation, by column

# %%
rows_missing = df_missing[df_missing.isnull().any(axis=1)]
df_interpolated = df_missing.interpolate(axis = 0)
rows_interpolated = df_interpolated.loc[rows_missing.index]

line1 = Line(
        rows_interpolated.loc[:,'Fresh':'Delicassen'], 
        title="Missing", 
        legend="top_right", 
        ylabel='Value'
    )
line2 = Line(
        rows_correct.loc[:,'Fresh':'Delicassen'], 
        title="Correct", 
        legend="top_right", 
        ylabel='Value'
    )


show(row(line1, line2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="84962f3e-2da5-4dc7-93cf-8b682dc97cb6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("84962f3e-2da5-4dc7-93cf-8b682dc97cb6");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("84962f3e-2da5-4dc7-93cf-8b682dc97cb6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '84962f3e-2da5-4dc7-93cf-8b682dc97cb6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"af0e3057-b2d3-49d2-a8ef-2641cd2d4750":{"roots":{"references":[{"attributes":{"line_color":{"value":"#5ab738"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"484f6d93-a9d5-4be2-a85b-0d3a52511ad9","type":"Line"},{"attributes":{"below":[{"id":"0f32d882-0869-46cb-9f1b-e61a5c6ab74d","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"0a3c2458-6fe0-42bb-8101-9c2c85907957","type":"LinearAxis"}],"renderers":[{"id":"7d56ea08-e1f0-4ae9-86aa-e5f976e22e34","type":"BoxAnnotation"},{"id":"1a9e58de-6ad1-4327-9d28-d0df5ca682ad","type":"GlyphRenderer"},{"id":"e7e6328d-d755-4496-a4a6-867394e981b6","type":"GlyphRenderer"},{"id":"01e354da-b81e-480e-a94b-6e0c9944bb5d","type":"GlyphRenderer"},{"id":"733dbab9-a8a6-45b1-98ff-7e7697631218","type":"GlyphRenderer"},{"id":"a369772c-be00-4c9c-b40a-21ac234196c5","type":"GlyphRenderer"},{"id":"7387e37a-2095-4942-8ef4-bff2e84e812e","type":"GlyphRenderer"},{"id":"d269cba1-ce5f-481e-810a-ab82259b4e88","type":"Legend"},{"id":"0f32d882-0869-46cb-9f1b-e61a5c6ab74d","type":"LinearAxis"},{"id":"0a3c2458-6fe0-42bb-8101-9c2c85907957","type":"LinearAxis"},{"id":"bf5896a3-8fae-45d5-9601-78f68e86c4cd","type":"Grid"},{"id":"57f90480-6ae7-48e9-bf17-4362155e8926","type":"Grid"}],"title":{"id":"e7f7a785-3192-4f86-b7bb-44ec2b81055c","type":"Title"},"toolbar":{"id":"3f111164-7662-4312-94f6-ae25d7ff6f94","type":"Toolbar"},"x_range":{"id":"eccea8bd-0866-4ef6-8d50-8e076c1e2977","type":"Range1d"},"x_scale":{"id":"bc947f55-cf7a-40bc-95df-7803972b29cf","type":"LinearScale"},"y_range":{"id":"454d4c15-f34e-49a6-92b1-6f980a640ab2","type":"Range1d"},"y_scale":{"id":"8c793a64-f7f9-4fbf-890b-d0795bc6742a","type":"LinearScale"}},"id":"85c91145-1dae-4792-8f9e-a14132d39984","subtype":"Chart","type":"Plot"},{"attributes":{"axis_label":"Value","formatter":{"id":"d4155ac2-64a3-4959-8bd6-89f3ee5dcc6c","type":"BasicTickFormatter"},"plot":{"id":"0aac9358-80ec-4447-b86d-338cff2fc513","subtype":"Chart","type":"Plot"},"ticker":{"id":"78267751-e794-4117-adb1-8beb126fb87b","type":"BasicTicker"}},"id":"f7ca7c49-43a1-45da-954c-bba7e7c7968e","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#c33ff3"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"0e6a54e2-3180-40eb-b7c4-363ca651e159","type":"Line"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"Fresh"},{"series":"Fresh"},{"series":"Fresh"},{"series":"Fresh"},{"series":"Fresh"},{"series":"Fresh"}],"series":["Fresh","Fresh","Fresh","Fresh","Fresh","Fresh"],"x_values":[75,172,180,225,274,370],"y_values":{"__ndarray__":"AAAAAIDr00AAAAAAANiNQAAAAAAAIshAAAAAAADEyEAAAAAAAPCLQAAAAADgX+NA","dtype":"float64","shape":[6]}}},"id":"854a6a21-93d2-4b3e-8e02-fb8f2c4e6fa3","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"Milk"},{"series":"Milk"},{"series":"Milk"},{"series":"Milk"},{"series":"Milk"},{"series":"Milk"}],"series":["Milk","Milk","Milk","Milk","Milk","Milk"],"x_values":[75,172,180,225,274,370],"y_values":[1137,5479,6036,3243,1703,3944]}},"id":"4299a010-4f33-43e0-9d43-84847585e067","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"7098fe06-6446-49ad-b9e5-a4a7f862c4ba","type":"ColumnDataSource"},"glyph":{"id":"7bb291e7-ea41-4bd9-9b1b-1046123f8545","type":"Line"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"8a29af12-b04b-4caf-b1e9-c6d6d5f2115c","type":"CDSView"}},"id":"01e354da-b81e-480e-a94b-6e0c9944bb5d","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#c33ff3"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"e865a496-1d61-4656-ac03-be9e8d9fb840","type":"Line"},{"attributes":{"label":{"value":"Detergents_Paper"},"renderers":[{"id":"5978773d-2013-4191-b1d2-2f51835317f3","type":"GlyphRenderer"}]},"id":"62353b1a-9c8a-45f4-80bb-803eb687e705","type":"LegendItem"},{"attributes":{"callback":null,"end":436 ...
